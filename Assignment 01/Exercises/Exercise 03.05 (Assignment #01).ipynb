# %% [markdown]
# # Exercise 03.05 (Assignment #01) — Solving a System of Linear Equations

# %%
import numpy as np

# %% [markdown]
# ## The system of equations
#
# $$2x + 3y = 5$$
# $$4x + y = 6$$
#
# Represent this system in matrix form `Ax = b`.

# %%
# TODO: define A (coefficient matrix) and b (right-hand side vector) as numpy arrays

# %% [markdown]
# ## Solving for x
#
# Use NumPy to solve `Ax = b` for the vector `x = [x, y]`.

# %%
# TODO: solve for x using numpy (look into np.linalg.solve)

# %% [markdown]
# ## Display the solution

# %%
# TODO: print the solution

# %% [markdown]
# ## Try a different system
#
# Test the same approach with a different system of equations.

# %%
# TODO: define a new A and b, solve, and display
