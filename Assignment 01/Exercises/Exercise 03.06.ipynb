# %% [markdown]
# # Exercise 03.06 — Eigenvalues and Eigenvectors

# %%
import numpy as np

# %% [markdown]
# ## The matrix C
#
# $$C = \begin{bmatrix} 4 & 1 \\ 2 & 3 \end{bmatrix}$$

# %%
# TODO: define C as a numpy array

# %% [markdown]
# ## Eigenvalues and eigenvectors
#
# Use NumPy to compute the eigenvalues and eigenvectors of `C`, and display the results.

# %%
# TODO: compute eigenvalues/eigenvectors (look into np.linalg.eig) and print them

# %% [markdown]
# ## Try a different matrix
#
# Test the same approach with a different 2x2 matrix.

# %%
# TODO: define a new matrix, compute and display its eigenvalues/eigenvectors
